# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('matches - matches.csv')

# %%
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.head(7) #by default 5
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# ...

# %%
data.tail(9) #by defauly 5
# Out:
#       id  season           city        date                  team1  \
# 627  628    2016         Raipur  2016-05-20    Sunrisers Hyderabad
# 628  629    2016  Visakhapatnam  2016-05-21        Kings XI Punjab
# 629  630    2016         Kanpur  2016-05-21         Mumbai Indians
# 630  631    2016        Kolkata  2016-05-22  Kolkata Knight Riders
# 631  632    2016         Raipur  2016-05-22       Delhi Daredevils
# 632  633    2016      Bangalore  2016-05-24          Gujarat Lions
# 633  634    2016          Delhi  2016-05-25    Sunrisers Hyderabad
# 634  635    2016          Delhi  2016-05-27          Gujarat Lions
# 635  636    2016      Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 627             Delhi Daredevils             Delhi Daredevils         field
# 628      Rising Pune Supergiants              Kings XI Punjab           bat
# ...

# %%
data.shape # returns tuple of (number of rows ,numbers of column)
# Out:
# (636, 18)

# %%
data.info()# gives an overview of table, type of data,missing values etc...
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
data.describe() #only works with int columns, gives overall mean,min,std etc..
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
type(data)#dataframes in panda are tables
# Out:
# pandas.core.frame.DataFrame

# %%
type(data['winner'])# serise is a single column or row
# Out:
# pandas.core.series.Series

# %%
data['winner']#fetching 1 column
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
data[['team1','team2','winner']]#multiple column fetching with submitting a list
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %% [markdown]
# # using iloc[]

# %%
data.iloc[0]# gives data of row
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-04-05
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
data.iloc[[1,50,500,550,600,635]]# fancy indexing only fetching specific row dafa
# Out:
#       id  season       city        date                    team1  \
# 1      2    2017       Pune  2017-04-06           Mumbai Indians
# 50    51    2017      Delhi  2017-05-12         Delhi Daredevils
# 500  501    2014  Ahmedabad  2014-05-19           Mumbai Indians
# 550  551    2015  Hyderabad  2015-05-02      Sunrisers Hyderabad
# 600  601    2016       Pune  2016-04-29  Rising Pune Supergiants
# 635  636    2016  Bangalore  2016-05-29      Sunrisers Hyderabad
#
#                            team2             toss_winner toss_decision  \
# 1         Rising Pune Supergiant  Rising Pune Supergiant         field
# 50        Rising Pune Supergiant        Delhi Daredevils           bat
# 500             Rajasthan Royals          Mumbai Indians           bat
# 550          Chennai Super Kings     Chennai Super Kings         field
# 600                Gujarat Lions           Gujarat Lions         field
# 635  Royal Challengers Bangalore     Sunrisers Hyderabad           bat
#
# ...

# %%
data.iloc[1:12:2]# like slicing also supports fancy indexing
# Out:
#     id  season       city        date                        team1  \
# 1    2    2017       Pune  2017-04-06               Mumbai Indians
# 3    4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 5    6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 7    8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 9   10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
# 11  12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
#
#                      team2                  toss_winner toss_decision  result  \
# 1   Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 3          Kings XI Punjab              Kings XI Punjab         field  normal
# 5      Sunrisers Hyderabad          Sunrisers Hyderabad         field  normal
# 7          Kings XI Punjab  Royal Challengers Bangalore           bat  normal
# 9           Mumbai Indians               Mumbai Indians         field  normal
# ...

# %%
data.iloc[[1,50,550,600,635],[2,6,7,10]]  # for both [row,column], also indexing in both ca be used
# Out:
#           city             toss_winner toss_decision                  winner
# 1         Pune  Rising Pune Supergiant         field  Rising Pune Supergiant
# 50       Delhi        Delhi Daredevils           bat        Delhi Daredevils
# 550  Hyderabad     Chennai Super Kings         field     Sunrisers Hyderabad
# 600       Pune           Gujarat Lions         field           Gujarat Lions
# 635  Bangalore     Sunrisers Hyderabad           bat     Sunrisers Hyderabad

# %% [markdown]
# # selecting on condition

# %%
mask1 = data['city'] == 'Hyderabad' #called masking and returns a bolean serise
mask2 = data['win_by_runs'] >= 12
mask3 = data['toss_decision'] == 'field'
mask1
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# Name: city, Length: 636, dtype: bool

# %%
data[mask1 & mask2 & mask3]
# Out:
#       id  season       city        date                   team1  \
# 0      1    2017  Hyderabad  2017-04-05     Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30     Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06  Rising Pune Supergiant
# 101  102    2008  Hyderabad  2008-05-18          Mumbai Indians
# 244  245    2011  Hyderabad  2011-04-14         Deccan Chargers
# 259  260    2011  Hyderabad  2011-04-24          Mumbai Indians
# 274  275    2011  Hyderabad  2011-05-03   Kolkata Knight Riders
# 358  359    2012  Hyderabad  2012-05-08         Kings XI Punjab
# 383  384    2013  Hyderabad  2013-04-05     Sunrisers Hyderabad
# 434  435    2013  Hyderabad  2013-05-08     Chennai Super Kings
# 550  551    2015  Hyderabad  2015-05-02     Sunrisers Hyderabad
# 597  598    2016  Hyderabad  2016-04-26     Sunrisers Hyderabad
# 602  603    2016  Hyderabad  2016-04-30     Sunrisers Hyderabad
#
# ...

# %% [markdown]
# # value_counts

# %%
# used on catagorical data columns where there are selected amount of options
myseries = data['winner'].value_counts()

# %%
data['id'].value_counts() # no real insight of doing this

# %%
# contains 2 columns --> 1.id it is unique, 2.other any column
myseries['Royal Challengers Bangalore']
# Out:
# 73

# %%
# to get unique matches played by teams
ms1 = data['team1'].value_counts()
ms2 = data['team2'].value_counts()

# %%
ms = (ms1+ms2) # mathamatical operations can be done with 2 serises with same id

# %% [markdown]
# # sort_values

# %%
(ms).sort_values().head(10) # by default ascending
# Out:
# Kochi Tuskers Kerala        14
# Rising Pune Supergiants     14
# Rising Pune Supergiant      16
# Gujarat Lions               30
# Pune Warriors               46
# Deccan Chargers             75
# Sunrisers Hyderabad         76
# Rajasthan Royals           118
# Chennai Super Kings        131
# Delhi Daredevils           147
# dtype: int64

# %%
(ms).sort_values(ascending=False).tail(10)
# Out:
# Delhi Daredevils           147
# Chennai Super Kings        131
# Rajasthan Royals           118
# Sunrisers Hyderabad         76
# Deccan Chargers             75
# Pune Warriors               46
# Gujarat Lions               30
# Rising Pune Supergiant      16
# Kochi Tuskers Kerala        14
# Rising Pune Supergiants     14
# dtype: int64

# %%
data.sort_values('city',ascending=True).head(7)
# does not change the original dataframe
# Out:
#       id  season       city        date                        team1  \
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# 457  458    2014  Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
#
#                      team2            toss_winner toss_decision  result  \
# 460       Rajasthan Royals       Rajasthan Royals         field  normal
# 471  Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 470       Rajasthan Royals       Rajasthan Royals         field  normal
# 464       Delhi Daredevils    Chennai Super Kings           bat  normal
# ...

# %%
data.sort_values('winner',ascending=False,inplace=False).tail(10)
#if we make inplace True then it will be permanently changed
# !!! caution before permanent changing the dataframe
# Out:
#       id  season        city        date                        team1  \
# 231  232    2010      Mumbai  2010-04-22          Chennai Super Kings
# 453  454    2013       Delhi  2013-05-21          Chennai Super Kings
# 553  554    2015     Chennai  2015-05-04          Chennai Super Kings
# 227  228    2010  Dharamsala  2010-04-18              Kings XI Punjab
# 221  222    2010     Chennai  2010-04-13        Kolkata Knight Riders
# 546  547    2015     Chennai  2015-04-28          Chennai Super Kings
# 489  490    2014      Mumbai  2014-05-10               Mumbai Indians
# 300  301    2011       Delhi  2011-05-21             Delhi Daredevils
# 545  546    2015   Bangalore  2015-04-29  Royal Challengers Bangalore
# 570  571    2015   Bangalore  2015-05-17             Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# 231              Deccan Chargers          Chennai Super Kings           bat
# ...

# %%
# first sorting with city
# then sorting with date
data.sort_values(['city','date'], ascending=[True,False])
# Out:
#       id  season       city        date                        team1  \
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# ..   ...     ...        ...         ...                          ...
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 461  462    2014        NaN  2014-04-19               Mumbai Indians
# 462  463    2014        NaN  2014-04-19        Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# # drop_duplicates

# %%
data.drop_duplicates(subset=['team'])
# Out:
#       id  season       city        date                   team1  \
# 0      1    2017  Hyderabad  2017-04-05     Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06          Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07           Gujarat Lions
# 3      4    2017     Indore  2017-04-08  Rising Pune Supergiant
# 5      6    2017  Hyderabad  2017-04-09           Gujarat Lions
# ..   ...     ...        ...         ...                     ...
# 630  631    2016    Kolkata  2016-05-22   Kolkata Knight Riders
# 632  633    2016  Bangalore  2016-05-24           Gujarat Lions
# 633  634    2016      Delhi  2016-05-25     Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27           Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29     Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
data.drop_duplicates(subset=['city'],keep='last',inplace=False)
# shows the last occurance and rejects every other oocurence by default it is first
# Out:
#       id  season            city        date                        team1  \
# 129  130    2009       Cape Town  2009-04-26              Kings XI Punjab
# 149  150    2009     East London  2009-05-08               Mumbai Indians
# 154  155    2009       Kimberley  2009-05-11              Deccan Chargers
# 161  162    2009  Port Elizabeth  2009-05-16               Mumbai Indians
# 164  165    2009    Bloemfontein  2009-05-17             Delhi Daredevils
# 168  169    2009          Durban  2009-05-20          Chennai Super Kings
# 171  172    2009       Centurion  2009-05-22             Delhi Daredevils
# 173  174    2009    Johannesburg  2009-05-24              Deccan Chargers
# 219  220    2010          Nagpur  2010-04-12              Deccan Chargers
# 277  278    2011           Kochi  2011-05-05         Kochi Tuskers Kerala
# 293  294    2011          Indore  2011-05-15             Rajasthan Royals
# 441  442    2013          Jaipur  2013-05-12          Chennai Super Kings
# ...

# %%
data.drop_duplicates(subset=['city','date'])# works like AND operations
#only where both are repeted then it will bw removed
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
ne = data.drop_duplicates(subset=['season'],keep='last')[['season','city','winner']].sort_values('season')

# %%
ne# gives me every season finalist winner
# Out:
#      season          city                 winner
# 116    2008        Mumbai       Rajasthan Royals
# 173    2009  Johannesburg        Deccan Chargers
# 233    2010        Mumbai    Chennai Super Kings
# 306    2011       Chennai    Chennai Super Kings
# 380    2012       Chennai  Kolkata Knight Riders
# 456    2013       Kolkata         Mumbai Indians
# 516    2014     Bangalore  Kolkata Knight Riders
# 575    2015       Kolkata         Mumbai Indians
# 635    2016     Bangalore    Sunrisers Hyderabad
# 58     2017     Hyderabad         Mumbai Indians

# %% [markdown]
# # groupby

# %%
gr = data.groupby('city')# groups dataframe depending on attribute

# %%
gr.size() # already sorted on attributes
# Out:
# city
# Abu Dhabi          7
# Ahmedabad         12
# Bangalore         66
# Bloemfontein       2
# Cape Town          7
# Centurion         12
# Chandigarh        46
# Chennai           48
# Cuttack            7
# Delhi             60
# Dharamsala         9
# Durban            15
# East London        3
# Hyderabad         49
# Indore             5
# Jaipur            33
# Johannesburg       8
# Kanpur             4
# Kimberley          3
# Kochi              5
# Kolkata           61
# Mumbai            85
# Nagpur             3
# Port Elizabeth     7
# Pune              32
# Raipur             6
# Rajkot            10
# Ranchi             7
# Sharjah            6
# Visakhapatnam     11
# dtype: int64

# %%
data.sort_values('city')['city'].value_counts()
# Out:
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Centurion         12
# Ahmedabad         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Cape Town          7
# Cuttack            7
# Ranchi             7
# Port Elizabeth     7
# Abu Dhabi          7
# Raipur             6
# Sharjah            6
# Indore             5
# Kochi              5
# Kanpur             4
# Nagpur             3
# Kimberley          3
# East London        3
# Bloemfontein       2
# Name: city, dtype: int64

# %%
gr.first() #gives first match from each city group
# Out:
#                  id  season        date                        team1  \
# city
# Abu Dhabi       458    2014  2014-04-16        Kolkata Knight Riders
# Ahmedabad       180    2010  2010-03-15             Rajasthan Royals
# Bangalore         5    2017  2017-04-08  Royal Challengers Bangalore
# Bloemfontein    161    2009  2009-05-15             Delhi Daredevils
# Cape Town       118    2009  2009-04-18               Mumbai Indians
# Centurion       133    2009  2009-04-28             Delhi Daredevils
# Chandigarh       32    2017  2017-04-28          Sunrisers Hyderabad
# Chennai          67    2008  2008-04-23          Chennai Super Kings
# Cuttack         186    2010  2010-03-19              Deccan Chargers
# Delhi            15    2017  2017-04-15             Delhi Daredevils
# Dharamsala      225    2010  2010-04-16              Kings XI Punjab
# Durban          123    2009  2009-04-21              Kings XI Punjab
# ...

# %%
gr.last()
# Out:
#                  id  season        date                        team1  \
# city
# Abu Dhabi       476    2014  2014-04-29             Rajasthan Royals
# Ahmedabad       540    2015  2015-04-24             Rajasthan Royals
# Bangalore       636    2016  2016-05-29          Sunrisers Hyderabad
# Bloemfontein    165    2009  2009-05-17             Delhi Daredevils
# Cape Town       130    2009  2009-04-26              Kings XI Punjab
# Centurion       172    2009  2009-05-22             Delhi Daredevils
# Chandigarh      622    2016  2016-05-15              Kings XI Punjab
# Chennai         563    2015  2015-05-10          Chennai Super Kings
# Cuttack         497    2014  2014-05-14               Mumbai Indians
# Delhi           635    2016  2016-05-27                Gujarat Lions
# Dharamsala      450    2013  2013-05-18              Kings XI Punjab
# Durban          169    2009  2009-05-20          Chennai Super Kings
# ...

# %%
gr.groups
# returns dictionari of key-> city, values-> index list
# Out:
# {'Abu Dhabi': [457, 459, 460, 464, 470, 471, 475], 'Ahmedabad': [179, 186, 194, 197, 481, 486, 497, 500, 525, 532, 535, 539], 'Bangalore': [4, 11, 16, 29, 41, 44, 56, 57, 59, 69, 73, 83, 89, 103, 110, 180, 183, 191, 196, 213, 216, 225, 241, 267, 279, 282, 290, 301, 311, 316, 325, 328, 349, 355, 366, 378, 382, 391, 400, 406, 410, 428, 431, 451, 480, 487, 491, 494, 509, 516, 524, 533, 537, 545, 549, 556, 570, 579, 586, 605, 610, 616, 619, 625, 632, 635], 'Bloemfontein': [160, 164], 'Cape Town': [117, 118, 119, 120, 123, 125, 129], 'Centurion': [132, 135, 136, 146, 147, 148, 155, 156, 165, 169, 170, 171], 'Chandigarh': [31, 34, 45, 47, 60, 68, 72, 80, 93, 96, 107, 176, 192, 195, 204, 214, 242, 255, 283, 286, 320, 329, 332, 339, 353, 365, 390, 399, 408, 435, 439, 447, 504, 508, 511, 543, 551, 565, 568, 578, 585, 588, 596, 611, 614, 621], 'Chennai': [66, 70, 78, 84, 90, 106, 109, 178, 189, 201, 205, 210, 221, 223, 234, 247, 261, 271, 275, 288, 296, 305, 306, 307, 319, 331, 333, 342, 346, 
# ...

# %%
gr.get_group('Kolkata')# returns dataframe of attribute groupe
# Out:
#       id  season     city        date                    team1  \
# 10    11    2017  Kolkata  2017-04-13          Kings XI Punjab
# 13    14    2017  Kolkata  2017-04-15    Kolkata Knight Riders
# 22    23    2017  Kolkata  2017-04-21    Kolkata Knight Riders
# 26    27    2017  Kolkata  2017-04-23    Kolkata Knight Riders
# 30    31    2017  Kolkata  2017-04-28         Delhi Daredevils
# ..   ...     ...      ...         ...                      ...
# 607  608    2016  Kolkata  2016-05-04    Kolkata Knight Riders
# 613  614    2016  Kolkata  2016-05-08    Kolkata Knight Riders
# 620  621    2016  Kolkata  2016-05-14  Rising Pune Supergiants
# 623  624    2016  Kolkata  2016-05-16    Kolkata Knight Riders
# 630  631    2016  Kolkata  2016-05-22    Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# 10         Kolkata Knight Riders        Kolkata Knight Riders         field
# ...

# %%
gr.sum(numeric_only=True)# only returns for numeric data columns
# Out:
#                    id  season  dl_applied  win_by_runs  win_by_wickets  \
# city
# Abu Dhabi        3263   14098           0          157              16
# Ahmedabad        4863   24156           0          180              38
# Bangalore       22299  132861           3         1263             232
# Bloemfontein      326    4018           0           14               6
# Cape Town         858   14063           1          145              18
# Centurion        1842   24108           1           81              49
# Chandigarh      15325   92582           0          576             167
# Chennai         15096   96554           0          715             111
# Cuttack          2534   14086           0           73              20
# Delhi           19600  120771           2          876             192
# Dharamsala       2949   18103           0          279              23
# Durban           2147   30135           1          159              33
# ...

# %%
gr['win_by_wickets'].mean()# same as before
# Out:
# city
# Abu Dhabi         2.285714
# Ahmedabad         3.166667
# Bangalore         3.515152
# Bloemfontein      3.000000
# Cape Town         2.571429
# Centurion         4.083333
# Chandigarh        3.630435
# Chennai           2.312500
# Cuttack           2.857143
# Delhi             3.200000
# Dharamsala        2.555556
# Durban            2.200000
# East London       2.333333
# Hyderabad         3.755102
# Indore            7.200000
# Jaipur            4.575758
# Johannesburg      4.375000
# Kanpur            5.500000
# Kimberley         3.333333
# Kochi             2.600000
# Kolkata           3.672131
# Mumbai            3.105882
# Nagpur            2.000000
# Port Elizabeth    3.142857
# Pune              3.062500
# Raipur            4.166667
# Rajkot            4.800000
# Ranchi            3.428571
# Sharjah           4.333333
# Visakhapatnam     2.000000
# Name: win_by_wickets, dtype: float64

# %% [markdown]
# # rename
